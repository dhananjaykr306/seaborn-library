# %% [markdown]
#     @Author: Dhananjay Kumar
#     @Date: 28-10-2024
#     @Last Modified by: Dhananjay Kumar
#     @Last Modified time: 28-10-2024
#     @Title : Seaborn Library

# %% [markdown]
# ### Why Seaborn?
#
# - provides a layer of abstraction hence simpler to use
# - better aesthetics
# - more graphs included

# %% [markdown]
# ### Seaborn Roadmap
#
# Types of Functions
#
# - Figure Level
# - Axis Level
#
# Main Classification
#
# - Relational Plot
# - Distribution Plot
# - Categorical Plot
# - Regression Plot
# - Matrix Plot
# - Multiplots
#
# https://seaborn.pydata.org/api.html

# %% [markdown]
# ### 1. Relational Plot
#
# - to see the statistical relation between 2 or more variables.
# - Bivariate Analysis
#
# Plots under this section
#
# - scatterplot
# - lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# relplot -> figure level -> square shape
tips= sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot-> axes level function
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# relplot -> figure level -> squareplot
sns.relplot(data= tips,x='total_bill',y = 'tip',kind = 'scatter')

# %%
# relplot -> figure level -> squareplot
sns.relplot(data= tips,x='total_bill',y = 'tip',kind = "line")

# %% [markdown]
# # HUE

# %%
# relplot -> figure level -> squareplot
sns.relplot(data= tips,x='total_bill',y = 'tip',kind = "scatter",hue="sex")

# %% [markdown]
# # Style

# %%
# relplot -> figure level -> squareplot
sns.relplot(data= tips,x='total_bill',y = 'tip',kind = "scatter",hue="sex",style='time')

# %%
# scatter using relplot -> size and hue,style
sns.relplot(data= tips,x='total_bill',y = 'tip',kind = "scatter",hue="sex",style='time',size='size')

# %%
# style semantics

# %%
# line plot
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp_df=gap[gap["iso_alpha"]=="IND"]
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
gap['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
# axes level function
sns.lineplot(data=temp_df,x="year",y="lifeExp",hue='country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# using relpplot
sns.relplot(data=temp_df,x="year",y="lifeExp",kind='scatter',hue='country',style='continent',size='pop')

# %%
temp=gap[gap['country'].isin(['India','Pakistan','China'])]
temp
sns.relplot(data=temp,x='year',y='lifeExp',kind='line',hue='country',)#size='pop')

# %%
temp=gap[gap['country'].isin(['India','Pakistan','China'])]
temp
sns.relplot(data=temp,x='year',y='lifeExp',kind='line',hue='country',)#size='pop')

# %%
temp=gap[gap['country'].isin(['India','Germany','Brazil'])]
temp
sns.lineplot(data=temp,x='year',y='lifeExp',hue='country',style='continent',size='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
temp=gap[gap['country'].isin(['India','Germany','Brazil'])]
temp
sns.relplot(kind='line',data=temp,x='year',y='lifeExp',hue='country',style='continent',size='continent')

# %%
# facet plot->figure level function-> work with relplot
# it will not work with scatterplot and lineplot
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex',row='day')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='line',col='sex',row='day')

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#col wrap
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter')

# %%
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col=gap['year'],col_wrap=4)

# %% [markdown]
# Distribution plots
# - Used for univariate analysis
# - used for find out the distribution
# - Range of the obsevation
# - central tendency
# - is the data binomial
# - are there outliers?
#
# Plots under distribution plot
# - histplot
# - kdeplot
# - rugplot

# %%
# figure level -> distplot
# axes level -> hisplot-> kdeplot -> rugplot

# %%
# plotting with univariate analysis
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,x='total_bill',kind='hist')

# %%
import numpy as np

# %%
sns.displot(data=tips,x='total_bill',kind='hist',bins=20)#np.arange(2,60,2))

# %%
sns.displot(data=tips,x='total_bill',kind='hist',bins=np.arange(2,60,2))

# %%
# countplot
sns.displot(data=tips,x='day',kind='hist')

# %%
# hue parameter
sns.displot(data=tips,x='tip',kind='hist',hue='sex')

# %%
# element -> steps
sns.displot(data=tips,x='tip',kind='hist',hue='sex',element='step')

# %%
 titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data=titanic,x='age',kind='hist',hue='sex',element='step')

# %%
sns.displot(data=titanic,x='age',hue='sex',kind='hist',element='step')

# %%
titanic[titanic['survived']==1]['sex'].value_counts()
# Out:
# sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
titanic[titanic['survived']==1].groupby('sex').size()
# Out:
# sex
# female    233
# male      109
# dtype: int64

# %%
# faceting using row and cols-> not work on histplotfunction
sns.displot(data=titanic,x='age',col='sex',kind='hist',element='step')

# %%
# kdeplot
# rather than using discrete bin, a kde plot smooths the obsevation with Gaussian kernel, producing a continious density estimate
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# y axis denote the probablity of the data
sns.kdeplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,x='total_bill',kind='kde')

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
# Rugplot

# Plot the marginal distributions by drawing ticks along the x and y axes

# This function is intended to complement other plots by showing the location of the individual observation in an unobstrusive way.

sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill',)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangle that tile the plot
# and then shows the count of observation within each rectangle with the fill color

sns.histplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(data=tips,x='total_bill',y='tip',kind='hist')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Bivariate kdeplot
# a bivariate KDE plot smoothes the (x,y) observations with a 2D Gaussian
#sns.displot(data=tips,x='total_bill',y='tip',kind='kde')
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2. Matrix
#     - Heatmap
#     - Clustermap

# %%
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
# heatmap
import pandas as pd
df = pd.pivot_table(data=gap,index='country',columns='year',values='lifeExp')

# %%
df
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.xlabel('year')
plt.imshow(df,cmap='viridis',aspect='auto')
plt.colorbar()

# %%
temp_df = gap.pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(15,15))
sns.heatmap(temp_df,cmap='viridis')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
df = gap[gap['continent']=='Europe']
df
df=df.pivot(columns='year',index='country',values='lifeExp')
plt.figure(figsize=(15,15))
sns.heatmap(df,cmap='viridis',annot=True)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
df = gap[gap['continent']=='Asia']
df
df=df.pivot(columns='year',index='country',values='lifeExp')
plt.figure(figsize=(15,15))
sns.heatmap(df,cmap='summer',annot=True,linewidth=0.5)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# clustermap
iris=px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(iris.iloc[:,0:4])

# %%
plt.figure(figsize=(15,7))
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True,height=10,aspect=2)
